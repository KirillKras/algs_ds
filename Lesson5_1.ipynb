# %%
import numpy as np
from sklearn import model_selection
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from Lesson5 import RandomForestClassificator, gini, get_dataset, accuracy

# %%
train_data, train_labels = get_dataset(n_samples=300, random_state=5)
#train_data, test_data, train_labels, test_labels = model_selection.train_test_split(data, labels,
#                                                                                        test_size=0.3,
#                                                                                        random_state=1)

# %%
def get_meshgrid(data, step=.05, border=1.2):
    x_min, x_max = data[:, 0].min() - border, data[:, 0].max() + border
    y_min, y_max = data[:, 1].min() - border, data[:, 1].max() + border
    return np.meshgrid(np.arange(x_min, x_max, step), np.arange(y_min, y_max, step))

colors = ListedColormap(['red', 'blue'])
light_colors = ListedColormap(['lightcoral', 'lightblue'])

# %%
print('Классификация на 1 дереве')
classifier1 = RandomForestClassificator().fit(train_data, train_labels, n_trees=1,
                                           min_leaf=5, max_leaf=100, max_deep=50)
y_pred_train1 = classifier1.predict(train_data)
print(f'Accuracy for train data = {accuracy(train_labels, y_pred_train1)}')
y_pred_test1 = classifier1.predict(test_data)
print(f'Accuracy for test data = {accuracy(test_labels, y_pred_test1)}')
# Out:
# Классификация на 1 дереве
# Accuracy for train data = 0.919047619047619
# Accuracy for test data = 0.9444444444444444

# %%
plt.figure(figsize = (16, 7))

# график обучающей выборки
plt.subplot(1,2,1)
xx, yy = get_meshgrid(train_data)
mesh_predictions = np.array(classifier1.predict(np.c_[xx.ravel(), yy.ravel()])).reshape(xx.shape)
plt.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
plt.scatter(train_data[:, 0], train_data[:, 1], c = train_labels, cmap = colors)
plt.title(f'Accuracy for train data = {accuracy(train_labels, y_pred_train1)}')

# график тестовой выборки
plt.subplot(1,2,2)
plt.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
plt.scatter(test_data[:, 0], test_data[:, 1], c = test_labels, cmap = colors)
plt.title(f'Accuracy for test data = {accuracy(test_labels, y_pred_test1)}')
# Out:
# Text(0.5, 1.0, 'Accuracy for test data = 0.9444444444444444')

# %%
print('Классификация на 3 деревьях')
classifier3 = RandomForestClassificator().fit(train_data, train_labels, n_trees=3,
                                             min_leaf=5, max_leaf=100, max_deep=50)
y_pred_train3 = classifier3.predict(train_data)
print(f'Accuracy for train data = {accuracy(train_labels, y_pred_train3)}')
y_pred_test3 = classifier3.predict(test_data)
print(f'Accuracy for test data = {accuracy(test_labels, y_pred_test3)}')
# Out:
# Классификация на 3 деревьях
# Accuracy for train data = 0.9238095238095239
# Accuracy for test data = 0.8888888888888888

# %%
plt.figure(figsize = (16, 7))

# график обучающей выборки
plt.subplot(1,2,1)
xx, yy = get_meshgrid(train_data)
mesh_predictions = np.array(classifier3.predict(np.c_[xx.ravel(), yy.ravel()])).reshape(xx.shape)
plt.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
plt.scatter(train_data[:, 0], train_data[:, 1], c = train_labels, cmap = colors)
plt.title(f'Accuracy for train data = {accuracy(train_labels, y_pred_train3)}')

# график тестовой выборки
plt.subplot(1,2,2)
plt.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
plt.scatter(test_data[:, 0], test_data[:, 1], c = test_labels, cmap = colors)
plt.title(f'Accuracy for test data = {accuracy(test_labels, y_pred_test3)}')
# Out:
# Text(0.5, 1.0, 'Accuracy for test data = 0.8888888888888888')

# %%
print('Классификация на 10 деревьях')
classifier10 = RandomForestClassificator().fit(train_data, train_labels, n_trees=10,
                                             min_leaf=5, max_leaf=100, max_deep=50)
y_pred_train10 = classifier10.predict(train_data)
print(f'Accuracy for train data = {accuracy(train_labels, y_pred_train10)}')
y_pred_test10 = classifier10.predict(test_data)
print(f'Accuracy for test data = {accuracy(test_labels, y_pred_test10)}')
# Out:
# Классификация на 10 деревьях
# Accuracy for train data = 0.9619047619047619
# Accuracy for test data = 0.9111111111111111

# %%
plt.figure(figsize = (16, 7))

# график обучающей выборки
plt.subplot(1,2,1)
xx, yy = get_meshgrid(train_data)
mesh_predictions = np.array(classifier10.predict(np.c_[xx.ravel(), yy.ravel()])).reshape(xx.shape)
plt.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
plt.scatter(train_data[:, 0], train_data[:, 1], c = train_labels, cmap = colors)
plt.title(f'Accuracy for train data = {accuracy(train_labels, y_pred_train10)}')

# график тестовой выборки
plt.subplot(1,2,2)
plt.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
plt.scatter(test_data[:, 0], test_data[:, 1], c = test_labels, cmap = colors)
plt.title(f'Accuracy for test data = {accuracy(test_labels, y_pred_test10)}')
# Out:
# Text(0.5, 1.0, 'Accuracy for test data = 0.9111111111111111')

# %%
print('Классификация на 50 деревьях')
classifier50 = RandomForestClassificator().fit(train_data, train_labels, n_trees=50,
                                           min_leaf=5, max_leaf=100, max_deep=50)
y_pred_train50 = classifier50.predict(train_data)
print(f'Accuracy for train data = {accuracy(train_labels, y_pred_train50)}')
y_pred_test50 = classifier50.predict(test_data)
print(f'Accuracy for test data = {accuracy(test_labels, y_pred_test50)}')
# Out:
# Классификация на 50 деревьях
# Accuracy for train data = 0.9666666666666667
# Accuracy for test data = 0.9444444444444444

# %%
plt.figure(figsize = (16, 7))

# график обучающей выборки
plt.subplot(1,2,1)
xx, yy = get_meshgrid(train_data)
mesh_predictions = np.array(classifier50.predict(np.c_[xx.ravel(), yy.ravel()])).reshape(xx.shape)
plt.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
plt.scatter(train_data[:, 0], train_data[:, 1], c = train_labels, cmap = colors)
plt.title(f'Accuracy for train data = {accuracy(train_labels, y_pred_train50)}')

# график тестовой выборки
plt.subplot(1,2,2)
plt.pcolormesh(xx, yy, mesh_predictions, cmap = light_colors)
plt.scatter(test_data[:, 0], test_data[:, 1], c = test_labels, cmap = colors)
plt.title(f'Accuracy for test data = {accuracy(test_labels, y_pred_test50)}')
# Out:
# Text(0.5, 1.0, 'Accuracy for test data = 0.9444444444444444')

# %%
a = np.array([1,2,3])
b = np.array([1,2,3])

# %%
np.array_equal(a, b)
# Out:
# True

# %%
classifier50 = RandomForestClassificator().fit(train_data, train_labels, n_trees=50,
                                           min_leaf=5, max_leaf=100, max_deep=50)

# %%
classifier50.out_indexes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-d7dbfce1b1ac> in <module>
# ----> 1 classifier50.out_indexes
#       2
#
# AttributeError: 'RandomForestClassificator' object has no attribute 'out_indexes'

# %%
def get_bootstrap(data, labels, n_trees):
    n_samples = data.shape[0]
    bootstrap = []
    
    data_set = set(range(data.shape[0]))
    b_data_set = set()

    for i in range(n_trees):
        b_data = np.zeros(data.shape)
        b_labels = np.zeros(labels.shape)

        for j in range(n_samples):
            sample_index = np.random.randint(0, n_samples - 1)
            b_data_set.add(sample_index)
            b_data[j] = data[sample_index]
            b_labels[j] = labels[sample_index]
        bootstrap.append((b_data, b_labels))
        out_indexes = data_set.difference(b_data_set)
        pass
        
        

    return bootstrap

data, labels = get_dataset()
res = get_bootstrap(data, labels, 100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-53-664b89c217ef> in <module>
#      25
#      26 data, labels = get_dataset()
# ---> 27 res = get_bootstrap(data, labels, 100)
#      28
#
# <ipython-input-53-664b89c217ef> in get_bootstrap(data, labels, n_trees)
#      18         bootstrap.append((b_data, b_labels))
#      19         out_indexes = data_set.difference(b_data_set)
# ---> 20         pass
#      21
#      22
#
# <ipython-input-53-664b89c217ef> in get_bootstrap(data, labels, n_trees)
#      18         bootstrap.append((b_data, b_labels))
#      19         out_indexes = data_set.difference(b_data_set)
# ---> 20         pass
#      21
#      22
#
# _pydevd_bundle/pydevd_cython_darwin_38_64.pyx in _pydevd_bundle.pydevd_cython_darwin_38_64.SafeCallWrapper.__call__()
#
# ...
